# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'PathID_demand.csv')

# %%
df1.tail(100)
# Out:
#        Path ID     ADV  Unnamed: 2  Unnamed: 3  Unnamed: 4  Origin  \
# 6049     70-27   15.33         NaN         NaN         NaN      70
# 6050    69-114   27.92         NaN         NaN         NaN      69
# 6051     74-88  176.74         NaN         NaN         NaN      74
# 6052    176-25   31.13         NaN         NaN         NaN     176
# 6053   190-192   32.09         NaN         NaN         NaN     190
# 6054    115-86  148.51         NaN         NaN         NaN     115
# 6055    66-122  114.71         NaN         NaN         NaN      66
# 6056    28-150   67.35         NaN         NaN         NaN      28
# 6057    145-69   13.95         NaN         NaN         NaN     145
# 6058     31-85   89.81         NaN         NaN         NaN      31
# 6059   185-117  189.52         NaN         NaN         NaN     185
# 6060   70-3081  187.40         NaN         NaN         NaN      70
# 6061    103-37   10.51         NaN         NaN         NaN     103
# ...

# %%
filter1 = df1['Path ID']=="70-29"

# %%
df1.loc[df1['Path ID']=="70-29"]['ADV']
# Out:
# 1    142.24
# Name: ADV, dtype: float64

# %%
df1['Path ID']
# Out:
# 0        192-165
# 1          70-29
# 2       108-3112
# 3         129-28
# 4         152-85
# 5        28-3114
# 6         177-54
# 7        127-181
# 8          60-85
# 9         192-64
# 10        100-69
# 11        66-177
# 12         43-47
# 13      131-3101
# 14         17-64
# 15        106-18
# 16         44-47
# 17       115-117
# 18        20-135
# 19         35-17
# 20         37-11
# 21         35-31
# 22         28-47
# 23        16-136
# 24         16-69
# 25         43-81
# 26         21-37
# 27      193-3112
# 28        16-108
# 29        156-16
#           ...
# 6119      110-85
# 6120    192-3114
# 6121     106-122
# 6122     114-142
# 6123       2-Nov
# 6124       43-43
# 6125      70-108
# 6126       21-70
# 6127      110-44
# 6128      18-111
# 6129    193-3071
# 6130      194-81
# 6131     142-145
# 6132       34-24
# 6133      114-88
# 6134      117-25
# 6135    190-3101
# 6136     108-179
# 6137       34-34
# 6138      11-115
# 6139       70-66
# ...
